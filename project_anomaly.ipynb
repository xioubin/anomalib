# %% [markdown]
# <a href="https://colab.research.google.com/github/xioubin/anomalib/blob/main/project_anomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Clone github repository**
#
# make direction of inference result folder

# %%
# !git clone https://github.com/xioubin/anomalib.git
# %cd anomalib
# %mkdir result
# Out:
# Cloning into 'anomalib'...
# remote: Enumerating objects: 6320, done.
# remote: Counting objects: 100% (6320/6320), done.
# remote: Compressing objects: 100% (2321/2321), done.
# remote: Total 6320 (delta 3915), reused 6320 (delta 3915), pack-reused 0
# Receiving objects: 100% (6320/6320), 39.64 MiB | 34.46 MiB/s, done.
# Resolving deltas: 100% (3915/3915), done.
# Filtering content: 100% (3/3), 1.79 GiB | 42.07 MiB/s, done.
# /content/anomalib

# %% [markdown]
# **install requirements**

# %%
# %pip install anomalib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.4/191.4 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.1/569.1 kB 41.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 43.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 42.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.6/581.6 kB 34.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ***Inference Section***
#
# -> change config and weights tag to change model, with:
# ---
#
# --config config_cfa.yaml --weights cfa.ckpt
#
# --config config_cflow.yaml --weights cflow.ckpt
#
# --config config_patchcore.yaml --weights patchcore.ckpt

# %%
# inferencing normal image
# No.1~No.5 is normal image

! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/1.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/2.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/3.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/4.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/5.bmp --output result
# Out:
# To use wandb logger install it using `pip install wandb`
# /usr/local/lib/python3.10/dist-packages/anomalib/config/config.py:238: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /usr/local/lib/python3.10/dist-packages/anomalib/config/config.py:275: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# ...

# %%
# inferencing abnormal image
# No.6~No.10 is abnormal image

! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/6.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/7.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/8.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/9.bmp --output result
! python tools/inference/lightning_inference.py --config config_patchcore.yaml --weights patchcore.ckpt --input images/10.bmp --output result
# Out:
# To use wandb logger install it using `pip install wandb`
# /usr/local/lib/python3.10/dist-packages/anomalib/config/config.py:238: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /usr/local/lib/python3.10/dist-packages/anomalib/config/config.py:275: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

for image in range(1,11):
  plt.figure()
  image_path = f'result/images/{image}.bmp'
  print(image_path)
  rst = plt.imread(image_path)
  plt.imshow(rst)
# Out:
# result/images/1.bmp
# result/images/2.bmp
# result/images/3.bmp
# result/images/4.bmp
# result/images/5.bmp
# result/images/6.bmp
# result/images/7.bmp
# result/images/8.bmp
# result/images/9.bmp
# result/images/10.bmp
